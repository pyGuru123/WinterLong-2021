# %% [markdown]
# <a href="https://colab.research.google.com/github/pyGuru123/Data-Analysis-and-Visualization/blob/main/WhatsApp%20Group%20Chat%20Analysis/chat_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WhatsApp Group Chat Analysis

# %% [markdown]
# This notebook analyses a exported .txt chat  file of science & technology based whatsapp group. To analyse your own chat .txt file, On your phone, go to the WhatsApp group and click the 3 dots in the top right. Then got to ‘More’ and to ‘Export chat’. Select omit media. You can then select where to save this.
#
# ![](https://miro.medium.com/max/1200/1*O9ERcJLSpFcdIG4Ry1ednA.png)

# %% [markdown]
# # Aim & Requirements

# %% [markdown]
# **Aim** : To Analyse group chats of a whatsapp group
#
# **Dataset** : Data is exported chat .txt file from a whatsapp group
#
# **Dependencies** : Wordcloud, Matplotlib, Pandas, Calplot
#
#
# The case study is divied into 10 parts:
#
# 1. Preprocessing chat text file : hiding phone numbers, converting multiline messages to single line.
# 2. Converting text file to ***Date, time - sender : message*** format.
# 3. Reading the text file as Pandas Dataframe.
# 4. Extracting date, time, sender & message as seperate columns.
# 5. Extracting chat data info / group Insight
# 6. Visualize number of message by each member.
# 7. Visualize number of messages sent each day.
# 8. Visualize Most common messaging time.
# 9. Visualize Most common words
# 10. Visualize Most common used emojis

# %%
# !pip install wordcloud
# !pip install calplot

# %%
import re
import datetime

import calplot
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
chat_file = 'your_file_path_here'

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Reading the text file

# %%
with open(chat_file) as f:
    data = f.read()
# print(data)

# %% [markdown]
# editing some phone numbers as i don't want to reveal

# %%
phone_regex = r'\+[0-9 ]+'
r = re.findall(phone_regex, data)
for num in r:
    n = num[:10] + ('*' * (len(num)-10))
    data = data.replace(num, n)

print(data[:2000])
# Out:
# 10/31/19, 8:48 AM - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 5/29/20, 6:09 PM - +91 98776 *****'s security code changed. Tap for more info.
# 5/29/20, 9:34 PM - +91 98776 *****'s security code changed. Tap for more info.
# 5/30/20, 8:52 AM - +91 75790 *****: <Media omitted>
# 5/30/20, 8:52 AM - +91 75790 *****: Trump Says US Will Terminate Relationship With WHO Today
# donald-trump who terminate-relation
# Trump Says US Will Terminate Relationship With WHO Today
# News & Articles
# donald-trump who terminate-relation
# President Donald Trump announced Friday that the United States is will be cutting ties with the World Health Organization 1 later today. From a report:
#
# “China has total control over the World Health Organization despite only paying $40 million per year compared to what the United States has been paying, which is approximately $450 million a year,” Trump said during a press conference. Trump has repeatedly criticized the WHO’s response to the coronavirus, which has hit the U.S. worse than any other country, amid scrutiny of his own administration’s response to the pandemic. Earlier this month, Trump threatened to permanently cut off U.S. funding of the WHO. In a letter, he said that if the WHO “does not commit to major substantive improvements within the next 30 days, I will make my temporary freeze of United States funding to the World Health Organization permanent and reconsider our membership in the organization.” On Friday, Trump said WHO “failed to make the requested a greatly needed reform” and the U.S. “will be today terminating our relationship with the World Health Organization and redirecting those funds to other worldwide and deserving urgent global public health needs.”
# 5/30/20, 10:52 AM - +91 99441 *****: Lol, almost whole usa depends on china, various American companies buy raw materials from China for product manufacturing. Even "apple" depend upon china.

# %% [markdown]
# Finding all the occurences of dates

# %%
date_regex = r'(\d+/\d+/\d+)'
date_span = [x.span() for x in re.finditer(date_regex, data)]

# %% [markdown]
# fixing chats, removing multiple new lines from messages, see it above

# %%
chats_fixed = ''
for span in range(len(date_span)-1):
    init = date_span[span][0]
    end = date_span[span+1][0]-1
    c = (data[init:end].replace('\n', ' ') + '###\n')
    chats_fixed += c

# %%
print(chats_fixed[:2000])
# Out:
# 10/31/19, 8:48 AM - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.###
# 5/29/20, 6:09 PM - +91 98776 *****'s security code changed. Tap for more info.###
# 5/29/20, 9:34 PM - +91 98776 *****'s security code changed. Tap for more info.###
# 5/30/20, 8:52 AM - +91 75790 *****: <Media omitted>###
# 5/30/20, 8:52 AM - +91 75790 *****: Trump Says US Will Terminate Relationship With WHO Today donald-trump who terminate-relation Trump Says US Will Terminate Relationship With WHO Today News & Articles donald-trump who terminate-relation President Donald Trump announced Friday that the United States is will be cutting ties with the World Health Organization 1 later today. From a report:  “China has total control over the World Health Organization despite only paying $40 million per year compared to what the United States has been paying, which is approximately $450 million a year,” Trump said during a press conference. Trump has repeatedly criticized the WHO’s response to the coronavirus, which has hit the U.S. worse than any other country, amid scrutiny of his own administration’s response to the pandemic. Earlier this month, Trump threatened to permanently cut off U.S. funding of the WHO. In a letter, he said that if the WHO “does not commit to major substantive improvements within the next 30 days, I will make my temporary freeze of United States funding to the World Health Organization permanent and reconsider our membership in the organization.” On Friday, Trump said WHO “failed to make the requested a greatly needed reform” and the U.S. “will be today terminating our relationship with the World Health Organization and redirecting those funds to other worldwide and deserving urgent global public health needs.”###
# 5/30/20, 10:52 AM - +91 99441 *****: Lol, almost whole usa depends on china, various American companies buy raw materials from China for product manufacturing. Even "apple" dep

# %% [markdown]
# Writing back to the text file

# %%
with open('WhatsApp Chat with SciTech Labs.txt', 'w') as f:
    f.write(chats_fixed)

# %% [markdown]
# Reading text file & converting to data frame

# %%
df = pd.read_csv('WhatsApp Chat with SciTech Labs.txt', sep = '###\n', engine = 'python', header=None, names = ['text'])
raw_df = df
df
# Out:
#                                                     text
# 0      10/31/19, 8:48 AM - Messages and calls are end...
# 1      5/29/20, 6:09 PM - +91 98776 *****'s security ...
# 2      5/29/20, 9:34 PM - +91 98776 *****'s security ...
# 3      5/30/20, 8:52 AM - +91 75790 *****: <Media omi...
# 4      5/30/20, 8:52 AM - +91 75790 *****: Trump Says...
# ...                                                  ...
# 10948  1/21/21, 4:21 PM - +91 96339 *****: <Media omi...
# 10949   1/21/21, 6:10 PM - SL Keshav: <Media omitted>###
# 10950  1/21/21, 6:15 PM - SL Keshav: That's awesome 👏...
# 10951  1/21/21, 6:15 PM - SL Keshav: Even world of an...
# 10952  1/21/21, 8:59 PM - +91 96339 *****: <Media omi...
#
# [10953 rows x 1 columns]

# %% [markdown]
# removing unnecessary messages from dataframe

# %%
numMedia = df.text.str.contains("<Media omitted").sum()
numLinks = df.text.str.contains("http").sum()
joined_ = df.text.str.contains("joined using").sum()
left_ = df.text.str.contains("left").sum()

df = df[~df.text.str.contains("'s security")]
df = df[~df.text.str.contains("Messages and calls")]
df = df[~df.text.str.contains("<Media omitted")]
df
# Out:
#                                                     text
# 4      5/30/20, 8:52 AM - +91 75790 *****: Trump Says...
# 5      5/30/20, 10:52 AM - +91 99441 *****: Lol, almo...
# 7            5/30/20, 11:28 AM - SL Princy: Russian 🤔###
# 9                    5/30/20, 12:04 PM - SL Keshav: 😂###
# 10     5/30/20, 4:24 PM - 鳳凰院凶真: Robert Pattinson sai...
# ...                                                  ...
# 10944  1/21/21, 4:08 PM - +49 176 62******: Today is ...
# 10945         1/21/21, 4:16 PM - +91 88303 *****: 😂😂😂###
# 10946  1/21/21, 4:18 PM - +91 95622 *****: CAMBRIDGE ...
# 10950  1/21/21, 6:15 PM - SL Keshav: That's awesome 👏...
# 10951  1/21/21, 6:15 PM - SL Keshav: Even world of an...
#
# [8811 rows x 1 columns]

# %% [markdown]
# function for extracting date from string

# %%
date_regex = r'^(\d+/\d+/\d+),'

def get_date(text):
    match = re.search(date_regex, text)
    if match:
        try:
            return datetime.datetime.strptime(match.group(1), '%m/%d/%y').date()
        except:
            return None
    return None

# %% [markdown]
# creating a new column date

# %%
# extracting date
df['date'] = df['text'].apply(lambda text: get_date(text))
df['date'] = pd.to_datetime(df['date'])
# removing dates with NaN values
df = df.dropna(how='any',axis=0)

# sorting date
df = df.sort_values(by='date')
df
# Out:
#                                                     text       date
# 4      5/30/20, 8:52 AM - +91 75790 *****: Trump Says... 2020-05-30
# 37     5/30/20, 11:34 PM - +961 70 26*****: Volume=4p... 2020-05-30
# 36     5/30/20, 11:09 PM - 鳳凰院凶真: Your knowledge is k... 2020-05-30
# 35     5/30/20, 11:06 PM - +92 333 35*****: Working &... 2020-05-30
# 34       5/30/20, 11:02 PM - +961 70 26*****: 6 hours### 2020-05-30
# ...                                                  ...        ...
# 10929    1/21/21, 12:52 PM - +91 70203 *****: 🤣🤣🤣🤣🤣🤣🤣### 2021-01-21
# 10927  1/21/21, 1:49 AM - +49 1573 7******: probably ... 2021-01-21
# 10950  1/21/21, 6:15 PM - SL Keshav: That's awesome 👏... 2021-01-21
# 10935  1/21/21, 3:14 PM - 鳳凰院凶真: It's just a small Py... 2021-01-21
# 10951  1/21/21, 6:15 PM - SL Keshav: Even world of an... 2021-01-21
#
# [8793 rows x 2 columns]

# %% [markdown]
# Extracting time

# %%
def get_time(text):
    t = text.split(',')[1].split('-')[0]
    return datetime.datetime.strptime(t.strip(), '%I:%M %p').strftime('%H:%M')

df['time'] = df['text'].apply(lambda text: get_time(text))

# sorting by date and time
df.sort_values(['date', 'time'], inplace=True)
df
# Out:
#                                                     text       date   time
# 4      5/30/20, 8:52 AM - +91 75790 *****: Trump Says... 2020-05-30  08:52
# 5      5/30/20, 10:52 AM - +91 99441 *****: Lol, almo... 2020-05-30  10:52
# 7            5/30/20, 11:28 AM - SL Princy: Russian 🤔### 2020-05-30  11:28
# 9                    5/30/20, 12:04 PM - SL Keshav: 😂### 2020-05-30  12:04
# 10     5/30/20, 4:24 PM - 鳳凰院凶真: Robert Pattinson sai... 2020-05-30  16:24
# ...                                                  ...        ...    ...
# 10944  1/21/21, 4:08 PM - +49 176 62******: Today is ... 2021-01-21  16:08
# 10945         1/21/21, 4:16 PM - +91 88303 *****: 😂😂😂### 2021-01-21  16:16
# 10946  1/21/21, 4:18 PM - +91 95622 *****: CAMBRIDGE ... 2021-01-21  16:18
# 10950  1/21/21, 6:15 PM - SL Keshav: That's awesome 👏... 2021-01-21  18:15
# 10951  1/21/21, 6:15 PM - SL Keshav: Even world of an... 2021-01-21  18:15
#
# [8793 rows x 3 columns]

# %% [markdown]
# Extracting sender name & messages

# %%
def get_sender(text):
    return text.split('-')[1].split(':')[0]

def get_message(text):
    m =  text.split('-')[1].split(':')
    if len(m) > 1:
        return m[1].strip('###')
    else:
        return None

df['sender'] = df['text'].apply(lambda text: get_sender(text))
df['message'] = df['text'].apply(lambda text: get_message(text))
df = df.dropna(how='any',axis=0)
del df['text']
df
# Out:
#             date  ...                                            message
# 4     2020-05-30  ...   Trump Says US Will Terminate Relationship Wit...
# 5     2020-05-30  ...   Lol, almost whole usa depends on china, vario...
# 7     2020-05-30  ...                                          Russian 🤔
# 9     2020-05-30  ...                                                  😂
# 10    2020-05-30  ...   Robert Pattinson said he worked for more than...
# ...          ...  ...                                                ...
# 10944 2021-01-21  ...   Today is the  21st day of the 21st year of th...
# 10945 2021-01-21  ...                                                😂😂😂
# 10946 2021-01-21  ...                                     CAMBRIDGE ....
# 10950 2021-01-21  ...                                  That's awesome 👏🏻
# 10951 2021-01-21  ...             Even world of ants is better than this
#
# [8235 rows x 4 columns]

# %% [markdown]
# # Exploring Data

# %%
data = df

# %% [markdown]
# ### Total number of members

# %%
len(data['sender'].unique())
# Out:
# 153

# %% [markdown]
# Number of Indians and International members

# %%
indian_nums = []
international_nums = []
phones = data['sender'].tolist()
for phone in phones:
    if '+91' in phone:
        if not phone in indian_nums:
            indian_nums.append(phone)
    else:
        if not phone in international_nums:
            international_nums.append(phone)

print('Indian members :', len(indian_nums))
print('International members :', len(international_nums))
# Out:
# Indian members : 113
# International members : 40

# %% [markdown]
# Number of days on which messages were sent

# %%
len(data['date'].unique())
# Out:
# 227

# %% [markdown]
# ### Number of messages by each member

# %%
m = data.groupby('sender')[['message']].count().reset_index().sort_values(by='message', ascending=False)
msg = m.head(20)
msg
# Out:
#                  sender  message
# 152               鳳凰院凶真     1624
# 18    +90 507 65*******      883
# 149           SL Keshav      773
# 135     +92 333 35*****      621
# 126     +91 98315 *****      454
# 150           SL Princy      395
# 32      +91 70203 *****      239
# 125     +91 98151 *****      213
# 57      +91 81141 *****      157
# 101     +91 94151 *****      135
# 146           SL Dhiraj      132
# 73      +91 87479 *****      122
# 50      +91 77384 *****      113
# 78      +91 88303 *****      112
# 13     +49 176 57******      109
# 86      +91 90168 *****      101
# 30     +91 6394 3******       99
# 143         SL Abhishek       92
# 17    +90 506 91*******       90
# 95      +91 93222 *****       77

# %%
plt.figure(figsize=(20,6))
plt.style.use('fivethirtyeight')
plt.grid(color='w', linestyle='solid')

plt.bar(msg['sender'], msg['message'], color='blue')
plt.plot(msg['sender'], msg['message'], color='green', linewidth=1)
plt.xticks(rotation=70)
plt.xlabel('Member')
plt.ylabel('Number of messages sent')
plt.savefig('most_messges.png')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 40179 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38498 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20982 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30495 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 40179 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38498 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20982 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30495 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### Number of messages sent each day

# %%
num_msg = data.groupby('date')[['message']].count().reset_index()
sorted_num_msg = num_msg.sort_values(by='message')
num_msg
# Out:
#           date  message
# 0   2020-05-30       25
# 1   2020-05-31       49
# 2   2020-06-01       40
# 3   2020-06-02       98
# 4   2020-06-03      128
# ..         ...      ...
# 222 2021-01-17       27
# 223 2021-01-18        3
# 224 2021-01-19       12
# 225 2021-01-20       19
# 226 2021-01-21       18
#
# [227 rows x 2 columns]

# %% [markdown]
# Print maximum number of messages

# %%
print(num_msg[num_msg.message == num_msg.message.max()])
# Out:
#          date  message
# 58 2020-07-29      186

# %%
events = pd.Series(num_msg.message.tolist(), index=num_msg['date'])
calplot.calplot(events, edgecolor=None, cmap='YlGn', yearcolor='black', dropzero=True,)
# Out:
# (<Figure size 900x244.8 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f40a41e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3f40a37c88>],
#        dtype=object))

# %% [markdown]
# Messages sent per weekday

# %%
num_msg_weekday = data.groupby('day_of_week')[['message']].count().reset_index()
sorted_num_msg_weekday = num_msg_weekday.sort_values(by='message', ascending=False)
num_msg_weekday
# Out:
#    day_of_week  message
# 0            1     1024
# 1            2     1220
# 2            3     1356
# 3            4     1142
# 4            5     1389
# 5            6     1058
# 6            7     1046

# %%
plt.figure(figsize=(10,6))
plt.style.use('fivethirtyeight')
plt.grid(color='w', linestyle='solid')

plt.bar(num_msg_weekday['day_of_week'], num_msg_weekday['message'], color='purple')
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
index = [1,2,3,4,5,6,7]
plt.xticks(index, days)
plt.xlabel('Weekday')
plt.ylabel('Number of messages sent')
plt.savefig('Message_sent_each_weekday.png')
plt.show()

# %% [markdown]
# ### Most common messaging time

# %%
def get_hours(col):
    return int(col[:2])

data['day_of_week'] = data['date'].dt.dayofweek + 1
data['hour_of_day'] = data['time'].apply(lambda text : get_hours(text))

data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#             date   time  ... day_of_week hour_of_day
# 4     2020-05-30  08:52  ...           6           8
# 5     2020-05-30  10:52  ...           6          10
# 7     2020-05-30  11:28  ...           6          11
# 9     2020-05-30  12:04  ...           6          12
# 10    2020-05-30  16:24  ...           6          16
# ...          ...    ...  ...         ...         ...
# 10944 2021-01-21  16:08  ...           4          16
# 10945 2021-01-21  16:16  ...           4          16
# 10946 2021-01-21  16:18  ...           4          16
# 10950 2021-01-21  18:15  ...           4          18
# 10951 2021-01-21  18:15  ...           4          18
#
# [8235 rows x 6 columns]

# %%
heatmap_data = data.groupby(['day_of_week', 'hour_of_day']).size()
heatmap_data = heatmap_data.unstack()
heatmap_data
# Out:
# hour_of_day    0     1     2    3     4   ...    19     20     21     22    23
# day_of_week                               ...
# 1            41.0  34.0  16.0  3.0   6.0  ...  37.0   54.0  116.0   45.0  95.0
# 2            40.0  89.0   4.0  3.0   2.0  ...  95.0   77.0   80.0  118.0  96.0
# 3            56.0  22.0  60.0  5.0  13.0  ...  64.0  118.0  100.0   81.0  51.0
# 4            59.0  66.0   7.0  NaN   2.0  ...  64.0   36.0   79.0  114.0  75.0
# 5            46.0  40.0   6.0  2.0   3.0  ...  57.0  174.0  186.0  117.0  99.0
# 6            32.0  26.0  17.0  1.0   5.0  ...  89.0  145.0   54.0   61.0  64.0
# 7            42.0  21.0   6.0  2.0   2.0  ...  86.0   84.0   96.0   47.0  65.0
#
# [7 rows x 24 columns]

# %%
plt.figure(figsize=(15,5))
plt.style.use('ggplot')
plt.pcolor(heatmap_data, cmap='Reds')
plt.xlabel("Hour of Day")
plt.ylabel("Day of Week")
plt.colorbar()
plt.savefig('most_popular_hours.png')
plt.show()

# %% [markdown]
# Most busiest hours

# %%
hours_df = data.groupby('hour_of_day')[['message']].count().reset_index()
sorted_hours_df = hours_df.sort_values(by='message', ascending=False)
sorted_hours_df.head(10)
# Out:
#     hour_of_day  message
# 21           21      711
# 20           20      688
# 22           22      583
# 23           23      545
# 10           10      519
# 19           19      492
# 16           16      460
# 14           14      460
# 15           15      417
# 12           12      415

# %%
plt.figure(figsize=(16,6))
plt.style.use('fivethirtyeight')
plt.grid(color='w', linestyle='solid')

plt.bar(hours_df['hour_of_day'], hours_df['message'], color='green')
plt.xlabel('hours')
plt.ylabel('Number of messages sent')
plt.savefig('busiest_hours.png')
plt.show()

# %% [markdown]
# ### Most common words

# %%
wds_list = data['message'].tolist()
words = ''.join(wds_list)
words[:2000]
# Out:
# ' Trump Says US Will Terminate Relationship With WHO Today donald Lol, almost whole usa depends on china, various American companies buy raw materials from China for product manufacturing. Even "apple" depend upon china.  This means it doesn\'t matter if America stops funding to who. China will be still getting funding from umerica. Russian 🤔 😂 Robert Pattinson said he worked for more than 7 months on TENET and he has no idea of what he did 🤣😂😂🤣 😔😟 The starship is futuristic project as it is being designed to carry tonnes of cargo and humans to Mars and moon in upcoming projects The second attempt of Falcon 9\'s launch of Crew Dragon Demo Hope no casualties Nope it was just a prototype and was being tested safely for static fire Ohk🙏🏻 They are easier... If you still remember the related formulae. 1. l=3, then orbit is f  2. A d electron, then l=2 l=2, then n=3,4,5... ml=  😅 🙂 So remember we have a car in Space 👍🏻😯 Playtbeledon looks like a frikking nightmare https *Time conversion*  EDT  https Gta 6 car is better than this 6 hours Working & steps? Your knowledge is killing me Volume=4pi*r^3/3 Volume\'=Volume/64 r\' = r/4 same mass same speed t=24 hours t\'=6 hours 3rd step? Wait.. 🙃 So, t_prime will be always equal to t_o into cube root of the quotient? A question regarding infinity war... I hope it is not a spoiler? 😂 Can I ask? True 👍 or simply we have linear relation Yeah. *If I tell you what happens, it won\'t happen* Is there a name for this phenomenon? *endgame He\'s under lot of pressure Reverse countdown has started You can watch live from here A perfect liftoff, in a nominal trajectory 😍 The international space station Hello 👋🏻 Hey everyone Where are the math folks? 😂 I have a nice mental exercise that you\'ll love Go ahead please Ok, so here we go. The task is to use the information such as the number of vertices, lines, edges etc to tell the number of rectangles It\'s like, answering the question without seeing the figure, but using the geometric information I\'ve t'

# %%
from collections import Counter
most_frequent_words = Counter(words.split())

common_words = [word for word, word_count in most_frequent_words.most_common(350)]
print(common_words)
# Out:
# ['the', 'to', 'of', 'is', 'a', 'in', 'and', 'it', 'I', 'that', 'you', 'are', 'this', 'be', 'for', 'will', 'we', 'on', 'not', 'can', 'have', 'i', 'from', 'as', 'with', '😂', 'but', 'if', 'was', 'The', 'one', 'by', 'they', 'or', 'like', 'so', 'about', 'just', 'at', 'know', 'which', 'has', 'an', 'https', 'more', "it's", 'what', 'But', 'time', 'no', 'my', 'some', 'all', 'there', 'think', '😅', 'your', 'get', 'And', '?', 'then', 'our', 'This', 'how', 'only', 'am', 'than', 'do', "don't", 'first', 'me', 'he', '.', 'other', 'any', 'very', 'also', 'these', 'when', 'need', 'It', 'So', '&', 'its', 'them', 'would', 'their', 'here', 'You', 'two', "It's", 'now', 'see', 'were', 'may', 'much', '🤔', 'same', 'make', 'even', 'What', 'new', 'If', 'why', 'up', 'Yeah', 'people', 'group', 'space', 'A', 'We', 'too', 'after', 'been', 'out', 'into', 'year', 'years', '😂😂', 'use', 'In', 'take', 'something', 'No', '2', 'his', 'got', 'Earth', 'different', 'where', 'number', "I'm", 'had', ',', 'should', 'did', 'mean', 'earth', 'still', '1', 'because', 'many', 'water', '3', 'planet', 'Is', 'way', 'who', 'find', 'us', 'thing', 'said', 'could', 'such', 'using', 'around', 'really', 'Can', 'used', 'go', 'Mars', 'They', "That's", 'right', 'say', 'going', 'already', 'good', 'next', 'someone', 'made', 'Oh', 'He', 'want', 'Yes', 'Thanks', 'solar', 'another', "didn't", 'Then', 'found', 'life', 'being', 'might', 'light', "that's", 'before', 'humans', 'problem', 'most', 'As', 'science', 'few', 'There', 'help', 'does', 'part', 'world', 'How', '👍', 'due', "can't", 'over', 'last', 'speed', 'u', 'moon', 'better', '=', 'each', 'answer', 'means', 'between', 'That', 'never', 'black', 'anyone', 'try', 'read', 'understand', 'come', 'point', 'Or', 'back', 'work', 'human', 'known', 'tell', 'name', 'possible', 'actually', 'guess', 'Why', 'those', 'both', 'give', 'Now', 'sure', 'bro', 'send', 'cannot', 'matter', 'Not', 'end', 'less', 'For', "doesn't", 'day', 'data', 'able', '🙂', 'question', '4', 'thought', 'start', 'called', 'sun', 'system', 'message', 'dont', 'great', 'universe', 'star', 'started', 'things', 'through', 'link', 'small', 'area', '*', "I'll", '5', 'since', 'today', 'million', 'whole', 'launch', 'every', 'own', 'share', 'language', 'Ok', 'future', '10', 'person', '(', 'Just', 'well', 'allowed', 'big', 'NASA', 'energy', 'let', 'video', 'always', 'it,', 'again', 'must', 'probably', 'far', 'theory', 'image', 'came', 'making', 'high', 'thinking', 'ice', 'seen', 'mission', '😂😂😂', 'please', 'learn', 'case', 'it.', 'surface', 'yet', '😁', 'quantum', 'Space', 'solution', 'doing', 'check', 'difference', 'Do', 'change', 'while', 'ever', '\U0001f97a', 'infinite', 'large', 'Like', 'looks', 'mass', 'heard', 'says', 'long', 'man', 'exist', 'hole', 'kind', 'lot', 'without', 'true', 'keep', 'per', 'anything', '😊', 'near', 'times', 'field']

# %%
important_words = ['😂', 'https', '😅', 'group', 'people', 'space', 'year', '😂😂', '🤔', 'Earth', 'different', 'water', 'planet','Mars',
                   'solar', 'Thanks', 'found', 'life', 'light', 'humans', 'science', 'world', '👍', 'speed', 'moon', 'answer', 'bro',
                   'matter', 'data', '🙂', 'sun', 'system', 'universe', 'star', 'started', 'million', 'launch', 'language', 'future',
                   'NASA', 'energy', 'theory', 'image', 'high', 'ice', 'mission', '😂😂😂', 'surface', 'quantum', 'infinite', 'mass',
                   'hole', '😊', 'time', 'field']
common_words = filter(lambda item : item not in important_words, common_words)
for word in common_words:
    if word in most_frequent_words:
        del most_frequent_words[word]

most_frequent = most_frequent_words.most_common(100)
print(most_frequent)
# Out:
# [('😂', 395), ('https', 234), ('time', 203), ('😅', 196), ('🤔', 112), ('people', 105), ('group', 105), ('space', 104), ('year', 93), ('😂😂', 91), ('Earth', 87), ('different', 85), ('water', 79), ('planet', 79), ('Mars', 71), ('Thanks', 65), ('solar', 65), ('found', 64), ('life', 64), ('light', 63), ('humans', 62), ('science', 62), ('world', 59), ('👍', 58), ('speed', 57), ('moon', 56), ('answer', 56), ('bro', 50), ('matter', 48), ('data', 47), ('🙂', 46), ('sun', 44), ('system', 44), ('universe', 44), ('star', 44), ('started', 43), ('million', 42), ('launch', 41), ('language', 41), ('future', 41), ('NASA', 40), ('energy', 40), ('theory', 37), ('image', 37), ('high', 37), ('ice', 37), ('mission', 37), ('😂😂😂', 37), ('surface', 36), ('quantum', 36), ('infinite', 35), ('mass', 34), ('hole', 34), ('😊', 33), ('field', 33), ('travel', 33), ('force', 33), ('second', 32), ('days', 32), ('Maybe', 32), ('species', 32), ('research', 32), ('past', 32), ('look', 32), ('real', 32), ('Wow', 32), ('Yea', 32), ('under', 31), ('👍🏻', 31), ('Because', 31), ('else', 31), ('+', 31), ('asteroid', 31), ('based', 31), ('old', 31), ('having', 31), ("there's", 31), ('type', 31), ('animals', 31), ('created', 31), ("isn't", 31), ('scientists', 31), ('getting', 30), ('When', 30), ('wont', 30), ('Any', 30), ('researchers', 30), ('May', 30), ('within', 30), ('👆', 30), ('though', 30), ('Well', 30), ('Thank', 30), ('inside', 29), ('quite', 29), ('simple', 29), ('him', 29), ('done', 29), ('power', 29), ('wrong', 29)]

# %%
wds = {}
for wd, count in most_frequent:
    if wd.isalpha():
        wds[wd] = count

# %%
plt.figure(figsize=(18,6))
plt.style.use('ggplot')
plt.bar(list(wds.keys())[:50], list(wds.values())[:50] )
plt.xticks(rotation=70)
plt.savefig('most_common_words.png')
plt.show()

# %%
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=wds)
plt.figure(figsize=(20,7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("most_frequent_wordcloud.png")

# %% [markdown]
# ### Most common emoji's

# %%
words[:2000]
# Out:
# ' Trump Says US Will Terminate Relationship With WHO Today donald Lol, almost whole usa depends on china, various American companies buy raw materials from China for product manufacturing. Even "apple" depend upon china.  This means it doesn\'t matter if America stops funding to who. China will be still getting funding from umerica. Russian 🤔 😂 Robert Pattinson said he worked for more than 7 months on TENET and he has no idea of what he did 🤣😂😂🤣 😔😟 The starship is futuristic project as it is being designed to carry tonnes of cargo and humans to Mars and moon in upcoming projects The second attempt of Falcon 9\'s launch of Crew Dragon Demo Hope no casualties Nope it was just a prototype and was being tested safely for static fire Ohk🙏🏻 They are easier... If you still remember the related formulae. 1. l=3, then orbit is f  2. A d electron, then l=2 l=2, then n=3,4,5... ml=  😅 🙂 So remember we have a car in Space 👍🏻😯 Playtbeledon looks like a frikking nightmare https *Time conversion*  EDT  https Gta 6 car is better than this 6 hours Working & steps? Your knowledge is killing me Volume=4pi*r^3/3 Volume\'=Volume/64 r\' = r/4 same mass same speed t=24 hours t\'=6 hours 3rd step? Wait.. 🙃 So, t_prime will be always equal to t_o into cube root of the quotient? A question regarding infinity war... I hope it is not a spoiler? 😂 Can I ask? True 👍 or simply we have linear relation Yeah. *If I tell you what happens, it won\'t happen* Is there a name for this phenomenon? *endgame He\'s under lot of pressure Reverse countdown has started You can watch live from here A perfect liftoff, in a nominal trajectory 😍 The international space station Hello 👋🏻 Hey everyone Where are the math folks? 😂 I have a nice mental exercise that you\'ll love Go ahead please Ok, so here we go. The task is to use the information such as the number of vertices, lines, edges etc to tell the number of rectangles It\'s like, answering the question without seeing the figure, but using the geometric information I\'ve t'

# %%
regex = re.compile(u'([\U00002600-\U000027BF])|([\U0001f300-\U0001f64F])|([\U0001f680-\U0001f6FF])')
list_ = re.findall(regex, words)

emojis = []
for tup in list_:
    for ele in tup:
        if ele:
            emojis.append(ele)

emoji_count = Counter(emojis)
most_frequent = emoji_count.most_common(50)
print(most_frequent)
# Out:
# [('😂', 1012), ('😅', 362), ('🏻', 188), ('👍', 188), ('👏', 139), ('👌', 108), ('🙄', 95), ('😁', 92), ('🙂', 81), ('🙏', 61), ('♂', 56), ('😊', 50), ('😳', 42), ('😍', 39), ('👆', 36), ('😕', 35), ('😐', 32), ('🙃', 31), ('❤', 30), ('🏼', 27), ('🔥', 27), ('😄', 26), ('😎', 26), ('😌', 25), ('💯', 20), ('😆', 20), ('☹', 19), ('😃', 18), ('🙌', 16), ('😇', 14), ('😭', 14), ('😝', 14), ('😱', 14), ('😤', 13), ('😢', 12), ('❣', 12), ('😲', 12), ('🙁', 12), ('😏', 12), ('😯', 11), ('😶', 11), ('👀', 11), ('✌', 11), ('😟', 10), ('😉', 10), ('😑', 10), ('😜', 9), ('😨', 9), ('😀', 8), ('😒', 8)]

# %%
emoji_df = pd.DataFrame(list(emoji_count.items()), columns=['Emoji', 'Count'])
emoji_df = emoji_df.sort_values(by='Count', ascending=False)
emoji_df.head(15)
# Out:
#    Emoji  Count
# 0      😂   1012
# 5      😅    362
# 4      🏻    188
# 7      👍    188
# 48     👏    139
# 13     👌    108
# 20     🙄     95
# 26     😁     92
# 6      🙂     81
# 3      🙏     61
# 14     ♂     56
# 19     😊     50
# 66     😳     42
# 10     😍     39
# 12     👆     36

# %% [markdown]
# ### Message Insights

# %%
days_dict = {
    1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday', 7:'Sunday'
}

b_day = sorted_num_msg_weekday['day_of_week'].iloc[0]

# %%
print('First Message :', str(df['date'].iloc[0])[:10], df['time'].iloc[0])
print('Last Message :', str(df['date'].iloc[len(df)-1])[:10], df['time'].iloc[len(df)-1])
print('Number of days on which messages were sent :', len(data['date'].unique()))
print()

numMessages = len(df['date']) + numMedia
print('Total Messages sent :', numMessages)
print('Multimedia sent :', numMedia)
print('Total Emojis sent :', len(list_))
print('Total Links sent :', numLinks)
print()

print('Total Number of Members :', len(data['sender'].unique()))
print('Indian members :', len(indian_nums))
print('International members :', len(international_nums))
print('Members Joined :', joined_)
print('Members left :', left_)
print()

b_hour = sorted_hours_df['hour_of_day'].iloc[0]
if 0 <= b_hour <= 11:
    b_hour = f'{b_hour} AM'
else:
    b_hour = f'{b_hour} PM'

print('Most Messages sent by :', m['sender'].iloc[0])
print('Average message sent by members :', numMessages // len(m['sender']))
print('Average message sent per day :', numMessages // len(sorted_num_msg['date']))
print('Most Used Emoji :', emoji_df['Emoji'].iloc[0])
print('Most Messages sent on :', str(sorted_num_msg['date'].iloc[0])[:10])
print('Busiest Day :', days_dict[b_day])
print('Busiest Hour :', b_hour)
# Out:
# First Message : 2020-05-30 08:52
# Last Message : 2021-01-21 18:15
# Number of days on which messages were sent : 227
#
# Total Messages sent : 10183
# Multimedia sent : 1948
# Total Emojis sent : 3446
# Total Links sent : 297
#
# Total Number of Members : 153
# Indian members : 113
# International members : 40
# Members Joined : 140
# Members left : 131
#
# Most Messages sent by :  鳳凰院凶真
# Average message sent by members : 66
# Average message sent per day : 44
# Most Used Emoji : 😂
# Most Messages sent on : 2020-10-14
# Busiest Day : Friday
# Busiest Hour : 21 PM
